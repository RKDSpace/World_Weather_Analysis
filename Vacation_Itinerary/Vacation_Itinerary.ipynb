# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv(r"C:\Users\reshp\OneDrive\Desktop\DataClass\World_Weather_Analysis\Weather_Database\WeatherPy_Database.csv")
vacation_df.head()
# Out:
#    Unnamed: 0            City      Lat       Lng  Max Temp  Humidity  \
# 0           0  Cabo San Lucas  22.8909 -109.9124     84.51        81
# 1           1        Mbandaka   0.0487   18.2603     70.90        76
# 2           2      Walvis Bay -22.9575   14.5053     55.09        71
# 3           3          Albany  42.6001  -73.9662     73.63        72
# 4           4     New Norfolk -42.7826  147.0587     53.92        76
#
#    Cloudiness  Wind Speed Country                 Date       Description
# 0          27        3.00      MX  2022-08-01 01:51:49  scattered clouds
# 1         100        2.98      CD  2022-08-01 01:51:49   overcast clouds
# 2          14       10.36     NaN  2022-08-01 01:46:55        few clouds
# 3         100        2.28      US  2022-08-01 01:51:50   overcast clouds
# 4          54        4.00      AU  2022-08-01 01:51:51     broken clouds

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Weather Description</dt><dd>{Description}</dd>

</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]
print(hotel_info)
# Out:
# ['\n<dl>\n<dt>City</dt><dd>Cabo San Lucas</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>84.51 °F</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n\n</dl>\n', '\n<dl>\n<dt>City</dt><dd>Mbandaka</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Max Temp</dt><dd>70.9 °F</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n\n</dl>\n', '\n<dl>\n<dt>City</dt><dd>Walvis Bay</dd>\n<dt>Country</dt><dd>nan</dd>\n<dt>Max Temp</dt><dd>55.09 °F</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n\n</dl>\n', '\n<dl>\n<dt>City</dt><dd>Albany</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>73.63 °F</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n\n</dl>\n', '\n<dl>\n<dt>City</dt><dd>New Norfolk</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>53.92 °F</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n\n</dl>\n', '\n<dl>\n<dt>City</dt><dd>Saldanha</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Max Temp</dt><dd>50.31 °F</dd>\n<dt>Weather Description</dt>
# ...

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(32.0, 33.0), zoom_level=2)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_df.head()
# Out:
#    Unnamed: 0            City      Lat       Lng  Max Temp  Humidity  \
# 0           0  Cabo San Lucas  22.8909 -109.9124     84.51        81
# 1           1        Mbandaka   0.0487   18.2603     70.90        76
# 2           2      Walvis Bay -22.9575   14.5053     55.09        71
# 3           3          Albany  42.6001  -73.9662     73.63        72
# 4           4     New Norfolk -42.7826  147.0587     53.92        76
#
#    Cloudiness  Wind Speed Country                 Date       Description
# 0          27        3.00      MX  2022-08-01 01:51:49  scattered clouds
# 1         100        2.98      CD  2022-08-01 01:51:49   overcast clouds
# 2          14       10.36     NaN  2022-08-01 01:46:55        few clouds
# 3         100        2.28      US  2022-08-01 01:51:50   overcast clouds
# 4          54        4.00      AU  2022-08-01 01:51:51     broken clouds

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Pacific Grove"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Pacific Grove"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Laguna"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Carson City"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Fortuna"]

# %%
vacation_start.to_numpy()[0][2:4]
# Out:
# array([36.6177, -121.9166], dtype=object)

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start.to_numpy()[0][2:4]
end = vacation_start.to_numpy()[0][2:4]
stop1 = vacation_stop1.to_numpy()[0][2:4]
stop2 = vacation_stop2.to_numpy()[0][2:4]
stop3 = vacation_stop3.to_numpy()[0][2:4]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
city_itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')

fig.add_layer(city_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3,],ignore_index=True)

itinerary_df
# Out:
#    Unnamed: 0           City      Lat       Lng  Max Temp  Humidity  \
# 0        1032  Pacific Grove  36.6177 -121.9166     72.55        85
# 1        1164  Pacific Grove  36.6177 -121.9166     72.55        85
# 2         812         Laguna  38.4210 -121.4238     86.40        54
# 3        1220         Laguna  38.4210 -121.4238     86.40        54
# 4        1787         Laguna  38.4210 -121.4238     86.40        54
# 5        1462    Carson City  39.1638 -119.7674     90.73        36
# 6         516        Fortuna  40.5982 -124.1573     64.98        83
#
#    Cloudiness  Wind Speed Country                 Date      Description
# 0         100        3.00      US  2022-08-01 01:57:16  overcast clouds
# 1         100        3.00      US  2022-08-01 01:57:16  overcast clouds
# 2           0       12.66      US  2022-08-01 01:56:11        clear sky
# 3           0       12.66      US  2022-08-01 01:56:11        clear sky
# ...

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(39.1638,-119.7674), zoom_level=5)
heat_layer = gmaps.heatmap_layer(locations, dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
